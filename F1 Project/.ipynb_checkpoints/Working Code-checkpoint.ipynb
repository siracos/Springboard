# %%
import requests
import json
from pandas.io.json import json_normalize 
import os
import csv

# %%
iter_list = [{'active': True,
              'id': 4,
              'name': 'NDC',
              'type': 'DESTINATION'},
             {'active': True,
              'id': 3,
              'name': 'RDC',
              'details': {'conditions': [{'expression': 'Deposit',
                                         'matchType': 'EXACT',
                                         'type':'CATEGORY'},
                                         {'expression': 'success', 'matchType': 'EXACT', 'type': 'ACTION'},
                                         {'expression': 'RDC', 'matchType': 'EXACT', 'type': 'LABEL'}]},
              'type': 'EVENT'},
              {'active': True,
               'id': 2,
               'name': 'WITHDRAWAL',
               'details': {'conditions': [{'expression': 'Withdrawal',
                                          'matchType': 'EXACT',
                                          'type':'CATEGORY'},
                                          {'expression': 'success', 'matchType': 'EXACT', 'type': 'ACTION'},
                                          {'expression': 'WITH', 'matchType': 'EXACT', 'type': 'LABEL'}]},
               'type': 'EVENT'}]


for site in iter_list:
    base = '{} {} {} {}'.format(site['active'],site['id'],site['name'],site['type'])
    if 'details' in site:
        for trans in site['details']['conditions']:
            print('{} {} {} {}'.format(base, trans['expression'], trans['matchType'], trans['type']))
    else:
        print('{} NaN NaN NaN'.format(base))
# Out:
# True 4 NDC DESTINATION NaN NaN NaN
# True 3 RDC EVENT Deposit EXACT CATEGORY
# True 3 RDC EVENT success EXACT ACTION
# True 3 RDC EVENT RDC EXACT LABEL
# True 2 WITHDRAWAL EVENT Withdrawal EXACT CATEGORY
# True 2 WITHDRAWAL EVENT success EXACT ACTION
# True 2 WITHDRAWAL EVENT WITH EXACT LABEL

# %%
iter_list = [{'active': True,
              'id': 4,
              'name': 'NDC',
              'type': 'DESTINATION'},
             {'active': True,
              'id': 3,
              'name': 'RDC',
              'details': {'conditions': [{'expression': 'Deposit',
                                         'matchType': 'EXACT',
                                         'type':'CATEGORY'},
                                         {'expression': 'success', 'matchType': 'EXACT', 'type': 'ACTION'},
                                         {'expression': 'RDC', 'matchType': 'EXACT', 'type': 'LABEL'}]},
              'type': 'EVENT'},
              {'active': True,
               'id': 2,
               'name': 'WITHDRAWAL',
               'details': {'conditions': [{'expression': 'Withdrawal',
                                          'matchType': 'EXACT',
                                          'type':'CATEGORY'},
                                          {'expression': 'success', 'matchType': 'EXACT', 'type': 'ACTION'},
                                          {'expression': 'WITH', 'matchType': 'EXACT', 'type': 'LABEL'}]},
               'type': 'EVENT'}]
#-------------------------------------------------------------------------------------------------------------
for goal in iter_list:
    if 'details' in goal:
        for conditions in goal['details']['conditions']:
            print(goal['name'], goal['id'], goal['active'], conditions['expression'], conditions['matchType'], conditions['type'])
    else:
            print(goal['name'], goal['id'], goal['active'], goal['type'])
# Out:
# NDC 4 True DESTINATION
# RDC 3 True Deposit EXACT CATEGORY
# RDC 3 True success EXACT ACTION
# RDC 3 True RDC EXACT LABEL
# WITHDRAWAL 2 True Withdrawal EXACT CATEGORY
# WITHDRAWAL 2 True success EXACT ACTION
# WITHDRAWAL 2 True WITH EXACT LABEL

# %%
for goal in iter_list:
        print(goal['name'], goal['id'], goal['active'])
# Out:
# NDC 4 True
# RDC 3 True
# WITHDRAWAL 2 True

# %%
#Inital testing to see the data structure
r = requests.get("https://ergast.com/api/f1/2012/results/1.json")
                 
jasondict = r.json()
jsondat = jasondict['MRData']['RaceTable']
jsondat
# Out:
# {'season': '2012',
#  'position': '1',
#  'Races': [{'season': '2012',
#    'round': '1',
#    'url': 'http://en.wikipedia.org/wiki/2012_Australian_Grand_Prix',
#    'raceName': 'Australian Grand Prix',
#    'Circuit': {'circuitId': 'albert_park',
#     'url': 'http://en.wikipedia.org/wiki/Melbourne_Grand_Prix_Circuit',
#     'circuitName': 'Albert Park Grand Prix Circuit',
#     'Location': {'lat': '-37.8497',
#      'long': '144.968',
#      'locality': 'Melbourne',
#      'country': 'Australia'}},
#    'date': '2012-03-18',
#    'time': '06:00:00Z',
#    'Results': [{'number': '3',
#      'position': '1',
#      'positionText': '1',
#      'points': '25',
#      'Driver': {'driverId': 'button',
#       'permanentNumber': '22',
#       'code': 'BUT',
#       'url': 'http://en.wikipedia.org/wiki/Jenson_Button',
#       'givenName': 'Jenson',
#       'familyName': 'Button',
#       'dateOfBirth': '1980-01-19',
#       'nationality': 'British'},
#      'Constructor': {'constructorId': 'mclaren',
#       'url': 'http://en.wikipedia.org/wiki/McLaren',
#       'name': 'McLaren',
#       'nationality': 'British'},
#      'grid': '2',
#      'laps': '58',
#      'status': 'Finished',
#      'Time': {'millis': '5649565', 'time': '1:34:09.565'},
#      'FastestLap': {'rank': '1',
#       'lap': '56',
#       'Time': {'time': '1:29.187'},
#       'AverageSpeed': {'units': 'kph', 'speed': '214.053'}}}]},
#   {'season': '2012',
#    'round': '2',
#    'url': 'http://en.wikipedia.org/wiki/2012_Malaysian_Grand_Prix',
#    'raceName': 'Malaysian Grand Prix',
#    'Circuit': {'circuitId': 'sepang',
#     'url': 'http://en.wikipedia.org/wiki/Sepang_International_Circuit',
#     'circuitName': 'Sepang International Circuit',
#     'Location': {'lat': '2.76083',
#      'long': '101.738',
#      'locality': 'Kuala Lumpur',
#      'country': 'Malaysia'}},
#    'date': '2012-03-25',
#    'time': '08:00:00Z',
#    'Results': [{'number': '5',
#      'position': '1',
#      'positionText': '1',
#      'points': '25',
#      'Driver': {'driverId': 'alonso',
#       'permanentNumber': '14',
#       'code': 'ALO',
#       'url': 'http://en.wikipedia.org/wiki/Fernando_Alonso',
#       'givenName': 'Fernando',
#       'familyName': 'Alonso',
#       'dateOfBirth': '1981-07-29',
#       'nationality': 'Spanish'},
#      'Constructor': {'constructorId': 'ferrari',
#       'url': 'http://en.wikipedia.org/wiki/Scuderia_Ferrari',
#       'name': 'Ferrari',
#       'nationality': 'Italian'},
#      'grid': '8',
#      'laps': '56',
#      'status': 'Finished',
#      'Time': {'millis': '9891812', 'time': '2:44:51.812'},
#      'FastestLap': {'rank': '7',
#       'lap': '53',
#       'Time': {'time': '1:41.680'},
#       'AverageSpeed': {'units': 'kph', 'speed': '196.250'}}}]},
#   {'season': '2012',
#    'round': '3',
#    'url': 'http://en.wikipedia.org/wiki/2012_Chinese_Grand_Prix',
#    'raceName': 'Chinese Grand Prix',
#    'Circuit': {'circuitId': 'shanghai',
#     'url': 'http://en.wikipedia.org/wiki/Shanghai_International_Circuit',
#     'circuitName': 'Shanghai International Circuit',
#     'Location': {'lat': '31.3389',
#      'long': '121.22',
#      'locality': 'Shanghai',
#      'country': 'China'}},
#    'date': '2012-04-15',
#    'time': '07:00:00Z',
#    'Results': [{'number': '8',
#      'position': '1',
#      'positionText': '1',
#      'points': '25',
#      'Driver': {'driverId': 'rosberg',
#       'permanentNumber': '6',
#       'code': 'ROS',
#       'url': 'http://en.wikipedia.org/wiki/Nico_Rosberg',
#       'givenName': 'Nico',
#       'familyName': 'Rosberg',
#       'dateOfBirth': '1985-06-27',
#       'nationality': 'German'},
#      'Constructor': {'constructorId': 'mercedes',
#       'url': 'http://en.wikipedia.org/wiki/Mercedes-Benz_in_Formula_One',
#       'name': 'Mercedes',
#       'nationality': 'German'},
#      'grid': '1',
#      'laps': '56',
#      'status': 'Finished',
#      'Time': {'millis': '5786929', 'time': '1:36:26.929'},
#      'FastestLap': {'rank': '8',
#       'lap': '40',
#       'Time': {'time': '1:40.967'},
#       'AverageSpeed': {'units': 'kph', 'speed': '194.356'}}}]},
#   {'season': '2012',
#    'round': '4',
#    'url': 'http://en.wikipedia.org/wiki/2012_Bahrain_Grand_Prix',
#    'raceName': 'Bahrain Grand Prix',
#    'Circuit': {'circuitId': 'bahrain',
#     'url': 'http://en.wikipedia.org/wiki/Bahrain_International_Circuit',
#     'circuitName': 'Bahrain International Circuit',
#     'Location': {'lat': '26.0325',
#      'long': '50.5106',
#      'locality': 'Sakhir',
#      'country': 'Bahrain'}},
#    'date': '2012-04-22',
#    'time': '12:00:00Z',
#    'Results': [{'number': '1',
#      'position': '1',
#      'positionText': '1',
#      'points': '25',
#      'Driver': {'driverId': 'vettel',
#       'permanentNumber': '5',
#       'code': 'VET',
#       'url': 'http://en.wikipedia.org/wiki/Sebastian_Vettel',
#       'givenName': 'Sebastian',
#       'familyName': 'Vettel',
#       'dateOfBirth': '1987-07-03',
#       'nationality': 'German'},
#      'Constructor': {'constructorId': 'red_bull',
#       'url': 'http://en.wikipedia.org/wiki/Red_Bull_Racing',
#       'name': 'Red Bull',
#       'nationality': 'Austrian'},
#      'grid': '1',
#      'laps': '57',
#      'status': 'Finished',
#      'Time': {'millis': '5710990', 'time': '1:35:10.990'},
#      'FastestLap': {'rank': '1',
#       'lap': '41',
#       'Time': {'time': '1:36.379'},
#       'AverageSpeed': {'units': 'kph', 'speed': '202.151'}}}]},
#   {'season': '2012',
#    'round': '5',
#    'url': 'http://en.wikipedia.org/wiki/2012_Spanish_Grand_Prix',
#    'raceName': 'Spanish Grand Prix',
#    'Circuit': {'circuitId': 'catalunya',
#     'url': 'http://en.wikipedia.org/wiki/Circuit_de_Barcelona-Catalunya',
#     'circuitName': 'Circuit de Barcelona-Catalunya',
#     'Location': {'lat': '41.57',
#      'long': '2.26111',
#      'locality': 'Montmeló',
#      'country': 'Spain'}},
#    'date': '2012-05-13',
#    'time': '12:00:00Z',
#    'Results': [{'number': '18',
#      'position': '1',
#      'positionText': '1',
#      'points': '25',
#      'Driver': {'driverId': 'maldonado',
#       'permanentNumber': '13',
#       'code': 'MAL',
#       'url': 'http://en.wikipedia.org/wiki/Pastor_Maldonado',
#       'givenName': 'Pastor',
#       'familyName': 'Maldonado',
#       'dateOfBirth': '1985-03-09',
#       'nationality': 'Venezuelan'},
#      'Constructor': {'constructorId': 'williams',
#       'url': 'http://en.wikipedia.org/wiki/Williams_Grand_Prix_Engineering',
#       'name': 'Williams',
#       'nationality': 'British'},
#      'grid': '1',
#      'laps': '66',
#      'status': 'Finished',
#      'Time': {'millis': '5949145', 'time': '1:39:09.145'},
#      'FastestLap': {'rank': '6',
#       'lap': '26',
#       'Time': {'time': '1:27.906'},
#       'AverageSpeed': {'units': 'kph', 'speed': '190.635'}}}]},
#   {'season': '2012',
#    'round': '6',
#    'url': 'http://en.wikipedia.org/wiki/2012_Monaco_Grand_Prix',
#    'raceName': 'Monaco Grand Prix',
#    'Circuit': {'circuitId': 'monaco',
#     'url': 'http://en.wikipedia.org/wiki/Circuit_de_Monaco',
#     'circuitName': 'Circuit de Monaco',
#     'Location': {'lat': '43.7347',
#      'long': '7.42056',
#      'locality': 'Monte-Carlo',
#      'country': 'Monaco'}},
#    'date': '2012-05-27',
#    'time': '12:00:00Z',
#    'Results': [{'number': '2',
#      'position': '1',
#      'positionText': '1',
#      'points': '25',
#      'Driver': {'driverId': 'webber',
#       'code': 'WEB',
#       'url': 'http://en.wikipedia.org/wiki/Mark_Webber',
#       'givenName': 'Mark',
#       'familyName': 'Webber',
#       'dateOfBirth': '1976-08-27',
#       'nationality': 'Australian'},
#      'Constructor': {'constructorId': 'red_bull',
#       'url': 'http://en.wikipedia.org/wiki/Red_Bull_Racing',
#       'name': 'Red Bull',
#       'nationality': 'Austrian'},
#      'grid': '1',
#      'laps': '78',
#      'status': 'Finished',
#      'Time': {'millis': '6366557', 'time': '1:46:06.557'},
#      'FastestLap': {'rank': '3',
#       'lap': '45',
#       'Time': {'time': '1:18.805'},
#       'AverageSpeed': {'units': 'kph', 'speed': '152.579'}}}]},
#   {'season': '2012',
#    'round': '7',
#    'url': 'http://en.wikipedia.org/wiki/2012_Canadian_Grand_Prix',
#    'raceName': 'Canadian Grand Prix',
#    'Circuit': {'circuitId': 'villeneuve',
#     'url': 'http://en.wikipedia.org/wiki/Circuit_Gilles_Villeneuve',
#     'circuitName': 'Circuit Gilles Villeneuve',
#     'Location': {'lat': '45.5',
#      'long': '-73.5228',
#      'locality': 'Montreal',
#      'country': 'Canada'}},
#    'date': '2012-06-10',
#    'time': '18:00:00Z',
#    'Results': [{'number': '4',
#      'position': '1',
#      'positionText': '1',
#      'points': '25',
#      'Driver': {'driverId': 'hamilton',
#       'permanentNumber': '44',
#       'code': 'HAM',
#       'url': 'http://en.wikipedia.org/wiki/Lewis_Hamilton',
#       'givenName': 'Lewis',
#       'familyName': 'Hamilton',
#       'dateOfBirth': '1985-01-07',
#       'nationality': 'British'},
#      'Constructor': {'constructorId': 'mclaren',
#       'url': 'http://en.wikipedia.org/wiki/McLaren',
#       'name': 'McLaren',
#       'nationality': 'British'},
#      'grid': '2',
#      'laps': '70',
#      'status': 'Finished',
#      'Time': {'millis': '5549586', 'time': '1:32:29.586'},
#      'FastestLap': {'rank': '6',
#       'lap': '59',
#       'Time': {'time': '1:17.020'},
#       'AverageSpeed': {'units': 'kph', 'speed': '203.837'}}}]},
#   {'season': '2012',
#    'round': '8',
#    'url': 'http://en.wikipedia.org/wiki/2012_European_Grand_Prix',
#    'raceName': 'European Grand Prix',
#    'Circuit': {'circuitId': 'valencia',
#     'url': 'http://en.wikipedia.org/wiki/Valencia_Street_Circuit',
#     'circuitName': 'Valencia Street Circuit',
#     'Location': {'lat': '39.4589',
#      'long': '-0.331667',
#      'locality': 'Valencia',
#      'country': 'Spain'}},
#    'date': '2012-06-24',
#    'time': '12:00:00Z',
#    'Results': [{'number': '5',
#      'position': '1',
#      'positionText': '1',
#      'points': '25',
#      'Driver': {'driverId': 'alonso',
#       'permanentNumber': '14',
#       'code': 'ALO',
#       'url': 'http://en.wikipedia.org/wiki/Fernando_Alonso',
#       'givenName': 'Fernando',
#       'familyName': 'Alonso',
#       'dateOfBirth': '1981-07-29',
#       'nationality': 'Spanish'},
#      'Constructor': {'constructorId': 'ferrari',
#       'url': 'http://en.wikipedia.org/wiki/Scuderia_Ferrari',
#       'name': 'Ferrari',
#       'nationality': 'Italian'},
#      'grid': '11',
#      'laps': '57',
#      'status': 'Finished',
#      'Time': {'millis': '6256649', 'time': '1:44:16.649'},
#      'FastestLap': {'rank': '5',
#       'lap': '40',
#       'Time': {'time': '1:43.666'},
#       'AverageSpeed': {'units': 'kph', 'speed': '188.185'}}}]},
#   {'season': '2012',
#    'round': '9',
#    'url': 'http://en.wikipedia.org/wiki/2012_British_Grand_Prix',
#    'raceName': 'British Grand Prix',
#    'Circuit': {'circuitId': 'silverstone',
#     'url': 'http://en.wikipedia.org/wiki/Silverstone_Circuit',
#     'circuitName': 'Silverstone Circuit',
#     'Location': {'lat': '52.0786',
#      'long': '-1.01694',
#      'locality': 'Silverstone',
#      'country': 'UK'}},
#    'date': '2012-07-08',
#    'time': '12:00:00Z',
#    'Results': [{'number': '2',
#      'position': '1',
#      'positionText': '1',
#      'points': '25',
#      'Driver': {'driverId': 'webber',
#       'code': 'WEB',
#       'url': 'http://en.wikipedia.org/wiki/Mark_Webber',
#       'givenName': 'Mark',
#       'familyName': 'Webber',
#       'dateOfBirth': '1976-08-27',
#       'nationality': 'Australian'},
#      'Constructor': {'constructorId': 'red_bull',
#       'url': 'http://en.wikipedia.org/wiki/Red_Bull_Racing',
#       'name': 'Red Bull',
#       'nationality': 'Austrian'},
#      'grid': '2',
#      'laps': '52',
#      'status': 'Finished',
#      'Time': {'millis': '5111288', 'time': '1:25:11.288'},
#      'FastestLap': {'rank': '4',
#       'lap': '49',
#       'Time': {'time': '1:34.934'},
#       'AverageSpeed': {'units': 'kph', 'speed': '223.393'}}}]},
#   {'season': '2012',
#    'round': '10',
#    'url': 'http://en.wikipedia.org/wiki/2012_German_Grand_Prix',
#    'raceName': 'German Grand Prix',
#    'Circuit': {'circuitId': 'hockenheimring',
#     'url': 'http://en.wikipedia.org/wiki/Hockenheimring',
#     'circuitName': 'Hockenheimring',
#     'Location': {'lat': '49.3278',
#      'long': '8.56583',
#      'locality': 'Hockenheim',
#      'country': 'Germany'}},
#    'date': '2012-07-22',
#    'time': '12:00:00Z',
#    'Results': [{'number': '5',
#      'position': '1',
#      'positionText': '1',
#      'points': '25',
#      'Driver': {'driverId': 'alonso',
#       'permanentNumber': '14',
#       'code': 'ALO',
#       'url': 'http://en.wikipedia.org/wiki/Fernando_Alonso',
#       'givenName': 'Fernando',
#       'familyName': 'Alonso',
#       'dateOfBirth': '1981-07-29',
#       'nationality': 'Spanish'},
#      'Constructor': {'constructorId': 'ferrari',
#       'url': 'http://en.wikipedia.org/wiki/Scuderia_Ferrari',
#       'name': 'Ferrari',
#       'nationality': 'Italian'},
#      'grid': '1',
#      'laps': '67',
#      'status': 'Finished',
#      'Time': {'millis': '5465862', 'time': '1:31:05.862'},
#      'FastestLap': {'rank': '2',
#       'lap': '66',
#       'Time': {'time': '1:19.044'},
#       'AverageSpeed': {'units': 'kph', 'speed': '208.319'}}}]},
#   {'season': '2012',
#    'round': '11',
#    'url': 'http://en.wikipedia.org/wiki/2012_Hungarian_Grand_Prix',
#    'raceName': 'Hungarian Grand Prix',
#    'Circuit': {'circuitId': 'hungaroring',
#     'url': 'http://en.wikipedia.org/wiki/Hungaroring',
#     'circuitName': 'Hungaroring',
#     'Location': {'lat': '47.5789',
#      'long': '19.2486',
#      'locality': 'Budapest',
#      'country': 'Hungary'}},
#    'date': '2012-07-29',
#    'time': '12:00:00Z',
#    'Results': [{'number': '4',
#      'position': '1',
#      'positionText': '1',
#      'points': '25',
#      'Driver': {'driverId': 'hamilton',
#       'permanentNumber': '44',
#       'code': 'HAM',
#       'url': 'http://en.wikipedia.org/wiki/Lewis_Hamilton',
#       'givenName': 'Lewis',
#       'familyName': 'Hamilton',
#       'dateOfBirth': '1985-01-07',
#       'nationality': 'British'},
#      'Constructor': {'constructorId': 'mclaren',
#       'url': 'http://en.wikipedia.org/wiki/McLaren',
#       'name': 'McLaren',
#       'nationality': 'British'},
#      'grid': '1',
#      'laps': '69',
#      'status': 'Finished',
#      'Time': {'millis': '6065503', 'time': '1:41:05.503'},
#      'FastestLap': {'rank': '4',
#       'lap': '65',
#       'Time': {'time': '1:25.677'},
#       'AverageSpeed': {'units': 'kph', 'speed': '184.082'}}}]},
#   {'season': '2012',
#    'round': '12',
#    'url': 'http://en.wikipedia.org/wiki/2012_Belgian_Grand_Prix',
#    'raceName': 'Belgian Grand Prix',
#    'Circuit': {'circuitId': 'spa',
#     'url': 'http://en.wikipedia.org/wiki/Circuit_de_Spa-Francorchamps',
#     'circuitName': 'Circuit de Spa-Francorchamps',
#     'Location': {'lat': '50.4372',
#      'long': '5.97139',
#      'locality': 'Spa',
#      'country': 'Belgium'}},
#    'date': '2012-09-02',
#    'time': '12:00:00Z',
#    'Results': [{'number': '3',
#      'position': '1',
#      'positionText': '1',
#      'points': '25',
#      'Driver': {'driverId': 'button',
#       'permanentNumber': '22',
#       'code': 'BUT',
#       'url': 'http://en.wikipedia.org/wiki/Jenson_Button',
#       'givenName': 'Jenson',
#       'familyName': 'Button',
#       'dateOfBirth': '1980-01-19',
#       'nationality': 'British'},
#      'Constructor': {'constructorId': 'mclaren',
#       'url': 'http://en.wikipedia.org/wiki/McLaren',
#       'name': 'McLaren',
#       'nationality': 'British'},
#      'grid': '1',
#      'laps': '44',
#      'status': 'Finished',
#      'Time': {'millis': '5348530', 'time': '1:29:08.530'},
#      'FastestLap': {'rank': '10',
#       'lap': '40',
#       'Time': {'time': '1:54.293'},
#       'AverageSpeed': {'units': 'kph', 'speed': '220.611'}}}]},
#   {'season': '2012',
#    'round': '13',
#    'url': 'http://en.wikipedia.org/wiki/2012_Italian_Grand_Prix',
#    'raceName': 'Italian Grand Prix',
#    'Circuit': {'circuitId': 'monza',
#     'url': 'http://en.wikipedia.org/wiki/Autodromo_Nazionale_Monza',
#     'circuitName': 'Autodromo Nazionale di Monza',
#     'Location': {'lat': '45.6156',
#      'long': '9.28111',
#      'locality': 'Monza',
#      'country': 'Italy'}},
#    'date': '2012-09-09',
#    'time': '12:00:00Z',
#    'Results': [{'number': '4',
#      'position': '1',
#      'positionText': '1',
#      'points': '25',
#      'Driver': {'driverId': 'hamilton',
#       'permanentNumber': '44',
#       'code': 'HAM',
#       'url': 'http://en.wikipedia.org/wiki/Lewis_Hamilton',
#       'givenName': 'Lewis',
#       'familyName': 'Hamilton',
#       'dateOfBirth': '1985-01-07',
#       'nationality': 'British'},
#      'Constructor': {'constructorId': 'mclaren',
#       'url': 'http://en.wikipedia.org/wiki/McLaren',
#       'name': 'McLaren',
#       'nationality': 'British'},
#      'grid': '1',
#      'laps': '53',
#      'status': 'Finished',
#      'Time': {'millis': '4781221', 'time': '1:19:41.221'},
#      'FastestLap': {'rank': '5',
#       'lap': '52',
#       'Time': {'time': '1:28.427'},
#       'AverageSpeed': {'units': 'kph', 'speed': '235.841'}}}]},
#   {'season': '2012',
#    'round': '14',
#    'url': 'http://en.wikipedia.org/wiki/2012_Singapore_Grand_Prix',
#    'raceName': 'Singapore Grand Prix',
#    'Circuit': {'circuitId': 'marina_bay',
#     'url': 'http://en.wikipedia.org/wiki/Marina_Bay_Street_Circuit',
#     'circuitName': 'Marina Bay Street Circuit',
#     'Location': {'lat': '1.2914',
#      'long': '103.864',
#      'locality': 'Marina Bay',
#      'country': 'Singapore'}},
#    'date': '2012-09-23',
#    'time': '12:00:00Z',
#    'Results': [{'number': '1',
#      'position': '1',
#      'positionText': '1',
#      'points': '25',
#      'Driver': {'driverId': 'vettel',
#       'permanentNumber': '5',
#       'code': 'VET',
#       'url': 'http://en.wikipedia.org/wiki/Sebastian_Vettel',
#       'givenName': 'Sebastian',
#       'familyName': 'Vettel',
#       'dateOfBirth': '1987-07-03',
#       'nationality': 'German'},
#      'Constructor': {'constructorId': 'red_bull',
#       'url': 'http://en.wikipedia.org/wiki/Red_Bull_Racing',
#       'name': 'Red Bull',
#       'nationality': 'Austrian'},
#      'grid': '3',
#      'laps': '59',
#      'status': 'Finished',
#      'Time': {'millis': '7226144', 'time': '2:00:26.144'},
#      'FastestLap': {'rank': '3',
#       'lap': '50',
#       'Time': {'time': '1:52.134'},
#       'AverageSpeed': {'units': 'kph', 'speed': '162.865'}}}]},
#   {'season': '2012',
#    'round': '15',
#    'url': 'http://en.wikipedia.org/wiki/2012_Japanese_Grand_Prix',
#    'raceName': 'Japanese Grand Prix',
#    'Circuit': {'circuitId': 'suzuka',
#     'url': 'http://en.wikipedia.org/wiki/Suzuka_Circuit',
#     'circuitName': 'Suzuka Circuit',
#     'Location': {'lat': '34.8431',
#      'long': '136.541',
#      'locality': 'Suzuka',
#      'country': 'Japan'}},
#    'date': '2012-10-07',
#    'time': '06:00:00Z',
#    'Results': [{'number': '1',
#      'position': '1',
#      'positionText': '1',
#      'points': '25',
#      'Driver': {'driverId': 'vettel',
#       'permanentNumber': '5',
#       'code': 'VET',
#       'url': 'http://en.wikipedia.org/wiki/Sebastian_Vettel',
#       'givenName': 'Sebastian',
#       'familyName': 'Vettel',
#       'dateOfBirth': '1987-07-03',
#       'nationality': 'German'},
#      'Constructor': {'constructorId': 'red_bull',
#       'url': 'http://en.wikipedia.org/wiki/Red_Bull_Racing',
#       'name': 'Red Bull',
#       'nationality': 'Austrian'},
#      'grid': '1',
#      'laps': '53',
#      'status': 'Finished',
#      'Time': {'millis': '5336242', 'time': '1:28:56.242'},
#      'FastestLap': {'rank': '1',
#       'lap': '52',
#       'Time': {'time': '1:35.774'},
#       'AverageSpeed': {'units': 'kph', 'speed': '218.276'}}}]},
#   {'season': '2012',
#    'round': '16',
#    'url': 'http://en.wikipedia.org/wiki/2012_Korean_Grand_Prix',
#    'raceName': 'Korean Grand Prix',
#    'Circuit': {'circuitId': 'yeongam',
#     'url': 'http://en.wikipedia.org/wiki/Korean_International_Circuit',
#     'circuitName': 'Korean International Circuit',
#     'Location': {'lat': '34.7333',
#      'long': '126.417',
#      'locality': 'Yeongam County',
#      'country': 'Korea'}},
#    'date': '2012-10-14',
#    'time': '06:00:00Z',
#    'Results': [{'number': '1',
#      'position': '1',
#      'positionText': '1',
#      'points': '25',
#      'Driver': {'driverId': 'vettel',
#       'permanentNumber': '5',
#       'code': 'VET',
#       'url': 'http://en.wikipedia.org/wiki/Sebastian_Vettel',
#       'givenName': 'Sebastian',
#       'familyName': 'Vettel',
#       'dateOfBirth': '1987-07-03',
#       'nationality': 'German'},
#      'Constructor': {'constructorId': 'red_bull',
#       'url': 'http://en.wikipedia.org/wiki/Red_Bull_Racing',
#       'name': 'Red Bull',
#       'nationality': 'Austrian'},
#      'grid': '2',
#      'laps': '55',
#      'status': 'Finished',
#      'Time': {'millis': '5788651', 'time': '1:36:28.651'},
#      'FastestLap': {'rank': '5',
#       'lap': '55',
#       'Time': {'time': '1:42.499'},
#       'AverageSpeed': {'units': 'kph', 'speed': '197.211'}}}]},
#   {'season': '2012',
#    'round': '17',
#    'url': 'http://en.wikipedia.org/wiki/2012_Indian_Grand_Prix',
#    'raceName': 'Indian Grand Prix',
#    'Circuit': {'circuitId': 'buddh',
#     'url': 'http://en.wikipedia.org/wiki/Buddh_International_Circuit',
#     'circuitName': 'Buddh International Circuit',
#     'Location': {'lat': '28.3487',
#      'long': '77.5331',
#      'locality': 'Uttar Pradesh',
#      'country': 'India'}},
#    'date': '2012-10-28',
#    'time': '09:30:00Z',
#    'Results': [{'number': '1',
#      'position': '1',
#      'positionText': '1',
#      'points': '25',
#      'Driver': {'driverId': 'vettel',
#       'permanentNumber': '5',
#       'code': 'VET',
#       'url': 'http://en.wikipedia.org/wiki/Sebastian_Vettel',
#       'givenName': 'Sebastian',
#       'familyName': 'Vettel',
#       'dateOfBirth': '1987-07-03',
#       'nationality': 'German'},
#      'Constructor': {'constructorId': 'red_bull',
#       'url': 'http://en.wikipedia.org/wiki/Red_Bull_Racing',
#       'name': 'Red Bull',
#       'nationality': 'Austrian'},
#      'grid': '1',
#      'laps': '60',
#      'status': 'Finished',
#      'Time': {'millis': '5470744', 'time': '1:31:10.744'},
#      'FastestLap': {'rank': '4',
#       'lap': '60',
#       'Time': {'time': '1:28.723'},
#       'AverageSpeed': {'units': 'kph', 'speed': '207.950'}}}]},
#   {'season': '2012',
#    'round': '18',
#    'url': 'http://en.wikipedia.org/wiki/2012_Abu_Dhabi_Grand_Prix',
#    'raceName': 'Abu Dhabi Grand Prix',
#    'Circuit': {'circuitId': 'yas_marina',
#     'url': 'http://en.wikipedia.org/wiki/Yas_Marina_Circuit',
#     'circuitName': 'Yas Marina Circuit',
#     'Location': {'lat': '24.4672',
#      'long': '54.6031',
#      'locality': 'Abu Dhabi',
#      'country': 'UAE'}},
#    'date': '2012-11-04',
#    'time': '13:00:00Z',
#    'Results': [{'number': '9',
#      'position': '1',
#      'positionText': '1',
#      'points': '25',
#      'Driver': {'driverId': 'raikkonen',
#       'permanentNumber': '7',
#       'code': 'RAI',
#       'url': 'http://en.wikipedia.org/wiki/Kimi_R%C3%A4ikk%C3%B6nen',
#       'givenName': 'Kimi',
#       'familyName': 'Räikkönen',
#       'dateOfBirth': '1979-10-17',
#       'nationality': 'Finnish'},
#      'Constructor': {'constructorId': 'lotus_f1',
#       'url': 'http://en.wikipedia.org/wiki/Lotus_F1',
#       'name': 'Lotus F1',
#       'nationality': 'British'},
#      'grid': '4',
#      'laps': '55',
#      'status': 'Finished',
#      'Time': {'millis': '6358667', 'time': '1:45:58.667'},
#      'FastestLap': {'rank': '3',
#       'lap': '50',
#       'Time': {'time': '1:44.458'},
#       'AverageSpeed': {'units': 'kph', 'speed': '191.410'}}}]},
#   {'season': '2012',
#    'round': '19',
#    'url': 'http://en.wikipedia.org/wiki/2012_United_States_Grand_Prix',
#    'raceName': 'United States Grand Prix',
#    'Circuit': {'circuitId': 'americas',
#     'url': 'http://en.wikipedia.org/wiki/Circuit_of_the_Americas',
#     'circuitName': 'Circuit of the Americas',
#     'Location': {'lat': '30.1328',
#      'long': '-97.6411',
#      'locality': 'Austin',
#      'country': 'USA'}},
#    'date': '2012-11-18',
#    'time': '19:00:00Z',
#    'Results': [{'number': '4',
#      'position': '1',
#      'positionText': '1',
#      'points': '25',
#      'Driver': {'driverId': 'hamilton',
#       'permanentNumber': '44',
#       'code': 'HAM',
#       'url': 'http://en.wikipedia.org/wiki/Lewis_Hamilton',
#       'givenName': 'Lewis',
#       'familyName': 'Hamilton',
#       'dateOfBirth': '1985-01-07',
#       'nationality': 'British'},
#      'Constructor': {'constructorId': 'mclaren',
#       'url': 'http://en.wikipedia.org/wiki/McLaren',
#       'name': 'McLaren',
#       'nationality': 'British'},
#      'grid': '2',
#      'laps': '56',
#      'status': 'Finished',
#      'Time': {'millis': '5755269', 'time': '1:35:55.269'},
#      'FastestLap': {'rank': '5',
#       'lap': '55',
#       'Time': {'time': '1:39.709'},
#       'AverageSpeed': {'units': 'kph', 'speed': '199.047'}}}]},
#   {'season': '2012',
#    'round': '20',
#    'url': 'http://en.wikipedia.org/wiki/2012_Brazilian_Grand_Prix',
#    'raceName': 'Brazilian Grand Prix',
#    'Circuit': {'circuitId': 'interlagos',
#     'url': 'http://en.wikipedia.org/wiki/Aut%C3%B3dromo_Jos%C3%A9_Carlos_Pace',
#     'circuitName': 'Autódromo José Carlos Pace',
#     'Location': {'lat': '-23.7036',
#      'long': '-46.6997',
#      'locality': 'São Paulo',
#      'country': 'Brazil'}},
#    'date': '2012-11-25',
#    'time': '16:00:00Z',
#    'Results': [{'number': '3',
#      'position': '1',
#      'positionText': '1',
#      'points': '25',
#      'Driver': {'driverId': 'button',
#       'permanentNumber': '22',
#       'code': 'BUT',
#       'url': 'http://en.wikipedia.org/wiki/Jenson_Button',
#       'givenName': 'Jenson',
#       'familyName': 'Button',
#       'dateOfBirth': '1980-01-19',
#       'nationality': 'British'},
#      'Constructor': {'constructorId': 'mclaren',
#       'url': 'http://en.wikipedia.org/wiki/McLaren',
#       'name': 'McLaren',
#       'nationality': 'British'},
#      'grid': '2',
#      'laps': '71',
#      'status': 'Finished',
#      'Time': {'millis': '6322656', 'time': '1:45:22.656'},
#      'FastestLap': {'rank': '2',
#       'lap': '37',
#       'Time': {'time': '1:18.108'},
#       'AverageSpeed': {'units': 'kph', 'speed': '198.601'}}}]}]}

# %%
r = requests.get("https://ergast.com/api/f1/2018/results/1.json")
                 
jasondict = r.json()
jsondat = jasondict['MRData']['RaceTable']
jsondat
import os
import csv

# %%
    # get the json of 1000 rows into r , r is of type <class 'requests.models.Response'>
    r = requests.get(link)

    # get the data into a dictionary , data is of type dictionary
    data = r.json()
    r.close()

# %%
os.remove("myf1data.csv")
#Get the data from the JSON output.  Since the Diver and Constructor sections are lists
# of dictionaries, I had to normalize it and retrieve each one seperately
# The logic below retrieves the necessary field 
#Posittion, Race Name, Season/Year, Race Number, Race Date, DriverFirstName, DriverLastName, DriverID, StartingGrid#,ConstructorName


def load_into_csv(link, year,result):
    r = requests.get(link)
    data = r.json()
    r.close()
    data_df =data['MRData']['RaceTable']
    with open('myf1data.csv', 'a', newline='\n') as csvfile:
#csvwriter.writerow(['Posittion','RaceName','SeasonYear','RaceNumber','RaceDate','DriverFirstName','DriverLastName','DriverID','StartingGridNumb','ConstructorName'])
   
        for f1dat in [data_df]:
            for races in f1dat['Races']:
                for results in races['Results']:
                     for givenname in json_normalize(results['Driver'])['givenName']:
 
                         for famname in json_normalize(results['Driver'])['familyName']:
                            for driverid in json_normalize(results['Driver'])['driverId']:
                    
                                for construct in json_normalize(results['Constructor'])['name']:
 
                                    data = [f1dat['position'],races['raceName'],races['season'],races['round'],races['date'], 
                                  givenname, famname,driverid,results['grid'],construct]

                            
                                    csvwriter = csv.writer(csvfile)
                                    csvwriter.writerow(data)

                                    print(data)
    csvfile.close()

if __name__ == "__main__":

    year='2015'
    result = '1'
    is_first_year = True
    while int(year) <= 2018:
        link = 'https://ergast.com/api/f1/' + year + '/results/'+ result +'.json'
        load_into_csv(link, year,result)
        year = str(int(year)+1)
 
        is_first_year=False
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-419cdfc58ee8> in <module>
# ----> 1 os.remove("myf1data.csv")
#       2 #Get the data from the JSON output.  Since the Diver and Constructor sections are lists
#       3 # of dictionaries, I had to normalize it and retrieve each one seperately
#       4 # The logic below retrieves the necessary field
#       5 #Posittion, Race Name, Season/Year, Race Number, Race Date, DriverFirstName, DriverLastName, DriverID, StartingGrid#,ConstructorName
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'myf1data.csv'

# %%
print(data)
                
print(type(data))
# Out:
# ['1', 'Abu Dhabi Grand Prix', '2018', '21', '2018-11-25', 'Lewis', 'Hamilton', 'hamilton', '1', 'Mercedes']
# <class 'list'>

# %%
 explode(jsondat, lst_cols=list('BCDE'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-124-ea6da4124302> in <module>
# ----> 1 explode(jsondat, lst_cols=list('BCDE'))
#
# NameError: name 'explode' is not defined

# %%
import pandas as pd
from pandas.io.json import json_normalize



df= pd.concat([pd.DataFrame(jsondat), pd.DataFrame(list(jsondat[['Races']['Results']]))], axis=1).drop('Races', 1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-137-01a24e5720e7> in <module>
#       4
#       5
# ----> 6 df= pd.concat([pd.DataFrame(jsondat), pd.DataFrame(list(jsondat[['Races']['Results']]))], axis=1).drop('Races', 1)
#
# TypeError: list indices must be integers or slices, not str

# %%
df
# Out:
#   position round season                                            Circuit  \
# 0        1     1   2018  {'circuitId': 'albert_park', 'url': 'http://en...
#
#                                              Results        date  \
# 0  [{'number': '5', 'position': '1', 'positionTex...  2018-03-25
#
#                 raceName round season       time  \
# 0  Australian Grand Prix     1   2018  05:10:00Z
#
#                                                  url
# 0  https://en.wikipedia.org/wiki/2018_Australian_...

# %%
from pandas.io.json import json_normalize  
for f1dat in [jsondat]:
    for races in f1dat['Races']:
        for results in races['Results']:
            for drivers results.select("Driver.*"):
                print(f1dat['position'],races['raceName'],results['points'],results['positionText'])
# Out:
#   File "<ipython-input-150-9c139fdd659c>", line 5
#     for drivers results.select("Driver.*"):
#                       ^
# SyntaxError: invalid syntax

# %%
works_data = json_normalize(data=jsondat['Races'], record_path=['Results','Constructor'], meta= ['season'])

# %%
works_data
# Out:
#                0 season
# 0  constructorId   2018
# 1            url   2018
# 2           name   2018
# 3    nationality   2018

# %%
df = pd.DataFrame([[1, 2, 3, 4]], columns=['col1', 'col2', 'col1', 'col2'])
jsonized_df = df.to_json(orient='split')
jsonized_df
# Out:
# '{"columns":["col1","col2","col1","col2"],"index":[0],"data":[[1,2,3,4]]}'

# %%
print(works_data['laps'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'laps'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-261-707e75c5ec10> in <module>
# ----> 1 print(works_data['laps'])
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'laps'

# %%
print(works_data)
# Out:
#                                          Constructor  \
# 0  {'constructorId': 'ferrari', 'url': 'http://en...
#
#                                               Driver  \
# 0  {'driverId': 'vettel', 'permanentNumber': '5',...
#
#                                           FastestLap  \
# 0  {'rank': '4', 'lap': '53', 'Time': {'time': '1...
#
#                                            Time grid laps number points  \
# 0  {'millis': '5373283', 'time': '1:29:33.283'}    3   58      5     25
#
#   position positionText    status season
# 0        1            1  Finished   2018

# %%
works_data
# Out:
#                                          Constructor  \
# 0  {'constructorId': 'ferrari', 'url': 'http://en...
#
#                                               Driver  \
# 0  {'driverId': 'vettel', 'permanentNumber': '5',...
#
#                                           FastestLap  \
# 0  {'rank': '4', 'lap': '53', 'Time': {'time': '1...
#
#                                            Time grid laps number points  \
# 0  {'millis': '5373283', 'time': '1:29:33.283'}    3   58      5     25
#
#   position positionText    status season
# 0        1            1  Finished   2018
